# %% [markdown]
# # Build a song recommender system
#
# ##### salimt

# %%
import turicreate
import os

# %% [markdown]
# # Load some music data

# %%
d = os.getcwd() #Gets the current working directory
os.chdir("..")
song_data = turicreate.SFrame('./data/song_data.sframe/m_cccc16853452d1ed.frame_idx')

# %% [markdown]
# # Explore our data

# %%
song_data
# Out:
# Columns:
# 	user_id	str
# 	song_id	str
# 	listen_count	int
# 	title	str
# 	artist	str
# 	song	str
#
# Rows: 1116609
#
# Data:
# +-------------------------------+--------------------+--------------+
# |            user_id            |      song_id       | listen_count |
# +-------------------------------+--------------------+--------------+
# | b80344d063b5ccb3212f76538f... | SOAKIMP12A8C130995 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBBMDR12A8C13253B |      2       |
# | b80344d063b5ccb3212f76538f... | SOBXHDL12A81C204C0 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBYHAJ12A6701BF1D |      1       |
# | b80344d063b5ccb3212f76538f... | SODACBL12A8C13C273 |      1       |
# | b80344d063b5ccb3212f76538f... | SODDNQT12A6D4F5F7E |      5       |
# | b80344d063b5ccb3212f76538f... | SODXRTY12AB0180F3B |      1       |
# | b80344d063b5ccb3212f76538f... | SOFGUAY12AB017B0A8 |      1       |
# | b80344d063b5ccb3212f76538f... | SOFRQTD12A81C233C0 |      1       |
# ...

# %% [markdown]
# ## Show the most popular songs in the dataset

# %%
song_data['song'].show()
# Out:
# Materializing SArray
# ...

# %% [markdown]
# # Count the number of unique users in the data

# %%
users = song_data['user_id'].unique()

# %%
len(users)
# Out:
# 66346

# %% [markdown]
# # Create a song recommender

# %%
train_data,test_data = song_data.random_split(.8,seed=0)

# %% [markdown]
# ## Create a very simple popularity recommender

# %%
popularity_model = turicreate.popularity_recommender.create(train_data,
                                                           user_id = 'user_id',
                                                           item_id = 'song')
# Out:
# ...
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 893580 observations with 66085 users and 9952 items.
#     Data prepared in: 1.38826s
# 893580 observations to process; with 9952 unique items.

# %% [markdown]
# ## Use the popularity model to make some predictions

# %%
popularity_model.recommend(users=[users[0]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+--------+------+
# |            user_id            |              song              | score  | rank |
# +-------------------------------+--------------------------------+--------+------+
# | c66c10a9567f0d82ff31441a9f... |    Sehr kosmisch - Harmonia    | 4754.0 |  1   |
# | c66c10a9567f0d82ff31441a9f... |          Undo - Björk          | 4227.0 |  2   |
# | c66c10a9567f0d82ff31441a9f... | You're The One - Dwight Yoakam | 3781.0 |  3   |
# | c66c10a9567f0d82ff31441a9f... | Dog Days Are Over (Radio E...  | 3633.0 |  4   |
# | c66c10a9567f0d82ff31441a9f... |    Revelry - Kings Of Leon     | 3527.0 |  5   |
# | c66c10a9567f0d82ff31441a9f... | Horn Concerto No. 4 in E f...  | 3161.0 |  6   |
# | c66c10a9567f0d82ff31441a9f... |     Secrets - OneRepublic      | 3148.0 |  7   |
# ...

# %%
popularity_model.recommend(users=[users[1]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+--------+------+
# |            user_id            |              song              | score  | rank |
# +-------------------------------+--------------------------------+--------+------+
# | 279292bb36dbfc7f505e36ebf0... |    Sehr kosmisch - Harmonia    | 4754.0 |  1   |
# | 279292bb36dbfc7f505e36ebf0... |          Undo - Björk          | 4227.0 |  2   |
# | 279292bb36dbfc7f505e36ebf0... | You're The One - Dwight Yoakam | 3781.0 |  3   |
# | 279292bb36dbfc7f505e36ebf0... | Dog Days Are Over (Radio E...  | 3633.0 |  4   |
# | 279292bb36dbfc7f505e36ebf0... |    Revelry - Kings Of Leon     | 3527.0 |  5   |
# | 279292bb36dbfc7f505e36ebf0... | Horn Concerto No. 4 in E f...  | 3161.0 |  6   |
# | 279292bb36dbfc7f505e36ebf0... |     Secrets - OneRepublic      | 3148.0 |  7   |
# ...

# %% [markdown]
# # Build a recommender with personalization

# %%
personalized_model = turicreate.item_similarity_recommender.create(train_data,
                                                                  user_id = 'user_id',
                                                                  item_id = 'song')
# Out:
# ...
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 893580 observations with 66085 users and 9952 items.
#     Data prepared in: 1.2246s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 1.6ms                          | 1.5        |
# | 31.906ms                       | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# ...

# %% [markdown]
# ## Apply personalized model to make song recommendations

# %%
personalized_model.recommend(users=[users[0]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |            user_id            |              song              |
# +-------------------------------+--------------------------------+
# | c66c10a9567f0d82ff31441a9f... | Cuando Pase El Temblor - S...  |
# | c66c10a9567f0d82ff31441a9f... | Fireflies - Charttraxx Karaoke |
# | c66c10a9567f0d82ff31441a9f... | Love Is A Losing Game - Am...  |
# | c66c10a9567f0d82ff31441a9f... |        Marry Me - Train        |
# | c66c10a9567f0d82ff31441a9f... |     Secrets - OneRepublic      |
# | c66c10a9567f0d82ff31441a9f... |    Sehr kosmisch - Harmonia    |
# | c66c10a9567f0d82ff31441a9f... | Te Hacen Falta Vitaminas -...  |
# | c66c10a9567f0d82ff31441a9f... | OMG - Usher featuring will...  |
# | c66c10a9567f0d82ff31441a9f... | Y solo se me ocurre amarte...  |
# | c66c10a9567f0d82ff31441a9f... |   No Dejes Que... - Caifanes   |
# ...

# %%
personalized_model.recommend(users=[users[1]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |            user_id            |              song              |
# +-------------------------------+--------------------------------+
# | 279292bb36dbfc7f505e36ebf0... | Riot In Cell Block Number ...  |
# | 279292bb36dbfc7f505e36ebf0... | Sei Lá Mangueira - Elizeth...  |
# | 279292bb36dbfc7f505e36ebf0... |      The Stallion - Ween       |
# | 279292bb36dbfc7f505e36ebf0... |        Rain - Subhumans        |
# | 279292bb36dbfc7f505e36ebf0... | West One (Shine On Me) - T...  |
# | 279292bb36dbfc7f505e36ebf0... | Back Against The Wall - Ca...  |
# | 279292bb36dbfc7f505e36ebf0... | Life Less Frightening - Ri...  |
# | 279292bb36dbfc7f505e36ebf0... | A Beggar On A Beach Of Gol...  |
# | 279292bb36dbfc7f505e36ebf0... | Audience Of One - Rise Against |
# | 279292bb36dbfc7f505e36ebf0... | Blame It On The Boogie - T...  |
# ...

# %% [markdown]
# # Apply model to find similar songs in the data set

# %%
personalized_model.get_similar_items(['With Or Without You - U2'])
# Out:
# Columns:
# 	song	str
# 	similar	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +--------------------------+-------------------------------+
# |           song           |            similar            |
# +--------------------------+-------------------------------+
# | With Or Without You - U2 | I Still Haven't Found What... |
# | With Or Without You - U2 | Hold Me_ Thrill Me_ Kiss M... |
# | With Or Without You - U2 |    Window In The Skies - U2   |
# | With Or Without You - U2 |          Vertigo - U2         |
# | With Or Without You - U2 |   Sunday Bloody Sunday - U2   |
# | With Or Without You - U2 |            Bad - U2           |
# | With Or Without You - U2 |     A Day Without Me - U2     |
# | With Or Without You - U2 | Another Time Another Place... |
# | With Or Without You - U2 |          Walk On - U2         |
# | With Or Without You - U2 |     Get On Your Boots - U2    |
# +--------------------------+-------------------------------+
# ...

# %%
personalized_model.get_similar_items(['Chan Chan (Live) - Buena Vista Social Club'])
# Out:
# Columns:
# 	song	str
# 	similar	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |              song             |            similar             |
# +-------------------------------+--------------------------------+
# | Chan Chan (Live) - Buena V... | Murmullo - Buena Vista Soc...  |
# | Chan Chan (Live) - Buena V... | La Bayamesa - Buena Vista ...  |
# | Chan Chan (Live) - Buena V... | Amor de Loca Juventud - Bu...  |
# | Chan Chan (Live) - Buena V... |   Diferente - Gotan Project    |
# | Chan Chan (Live) - Buena V... |       Mistica - Orishas        |
# | Chan Chan (Live) - Buena V... | Hotel California - Gipsy Kings |
# | Chan Chan (Live) - Buena V... |     Nací Orishas - Orishas     |
# | Chan Chan (Live) - Buena V... |     Gitana - Willie Colon      |
# | Chan Chan (Live) - Buena V... |    Le Moulin - Yann Tiersen    |
# | Chan Chan (Live) - Buena V... |    Criminal - Gotan Project    |
# ...

# %% [markdown]
# # Compare the models quantitatively
# We now formally compare the popularity and the personalized models using precision-recall curves.

# %%
model_performance = turicreate.recommender.util.compare_models(test_data, [popularity_model, personalized_model], user_sample=.05)
# Out:
# compare_models: using 2931 users to estimate model performance
# PROGRESS: Evaluate model M0
# recommendations finished on 1000/2931 queries. users per second: 12423.7
# recommendations finished on 2000/2931 queries. users per second: 12698.6
# WARNING:root:Model trained without a target. Skipping RMSE computation.
# Precision and recall summary statistics by cutoff
# +--------+----------------------+----------------------+
# | cutoff |    mean_precision    |     mean_recall      |
# +--------+----------------------+----------------------+
# |   1    | 0.02354145342886387  | 0.006681578022417322 |
# |   2    | 0.019788468099624704 | 0.01080194541044079  |
# |   3    | 0.018423746161719594 | 0.014908758881153368 |
# |   4    |  0.0183384510406005  | 0.019488454556038433 |
# |   5    | 0.017127260320709655 | 0.022431025461761817 |
# |   6    | 0.016376663254861833 | 0.025951008688530522 |
# |   7    | 0.01603548277038554  |  0.0298582463455424  |
# ...

# %% [markdown]
# The table shows that the personalized model provides much better performance.

# %%
popular_artist = turicreate.popularity_recommender.create(song_data,
                                                           user_id = 'user_id',
                                                           item_id = 'artist')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-f4d4896b09e0> in <module>
#       1 popular_artist = turicreate.popularity_recommender.create(song_data,
#       2                                                            user_id = users,
# ----> 3                                                            item_id = 'artist')
#
# ~/venv/lib/python3.6/site-packages/turicreate/toolkits/recommender/popularity_recommender.py in create(observation_data, user_id, item_id, target, user_data, item_data, random_seed, verbose)
#     103     extra_data = {"nearest_items": _turicreate.SFrame()}
#     104     with QuietProgress(verbose):
# --> 105         model_proxy.train(observation_data, user_data, item_data, opts, extra_data)
#     106
#     107     return PopularityRecommender(model_proxy)
#
# ...

# %%
a = song_data.groupby(key_column_names='artist',operations={'count': turicreate.aggregate.COUNT_DISTINCT('user_id')})
a.sort('count', ascending=False).print_rows(num_rows=30)
# Out:
# +-------------------------------+-------+
# |             artist            | count |
# +-------------------------------+-------+
# |         Kings Of Leon         |  7373 |
# |            Coldplay           |  6340 |
# |            Harmonia           |  5970 |
# |             Björk             |  5834 |
# |     Florence + The Machine    |  5615 |
# |             Train             |  5157 |
# |          OneRepublic          |  5100 |
# |         Dwight Yoakam         |  4806 |
# |        Alliance Ethnik        |  4067 |
# |             Eminem            |  3981 |
# | Barry Tuckwell/Academy of ... |  3949 |
# |           Metallica           |  3889 |
# |            Cartola            |  3853 |
# |         Justin Bieber         |  3745 |
# |           Radiohead           |  3732 |
# |          Linkin Park          |  3682 |
# |          The Killers          |  3676 |
# |        Black Eyed Peas        |  3631 |
# |              Muse             |  3504 |
# ...

# %%
b = song_data.groupby(key_column_names=['artist','listen_count'],operations={'count': turicreate.aggregate.COUNT()})
b.sort('listen_count', ascending=False).print_rows(num_rows=30)
# Out:
# +-----------------------------+--------------+-------+
# |            artist           | listen_count | count |
# +-----------------------------+--------------+-------+
# |        Righteous Pigs       |     920      |   1   |
# |        Darren Styles        |     796      |   1   |
# |        Dwight Yoakam        |     683      |   1   |
# |  The Lonely Island / T-Pain |     676      |   1   |
# |          Steely Dan         |     649      |   1   |
# |          Trey Songz         |     605      |   1   |
# |          HYPOCRISY          |     585      |   1   |
# |        Tracy Chapman        |     553      |   1   |
# |      Fergie / Ludacris      |     500      |   1   |
# |         Cat Stevens         |     500      |   1   |
# |        Kings Of Leon        |     488      |   1   |
# |    Mike And The Mechanics   |     453      |   1   |
# |        Dwight Yoakam        |     446      |   1   |
# | Cliff Richard & The Shadows |     431      |   1   |
# ...

# %%
b[b['artist']=='The Cool Kids']
# Out:
# Columns:
# 	artist	str
# 	listen_count	int
# 	count	int
#
# Rows: Unknown
#
# Data:
# +---------------+--------------+-------+
# |     artist    | listen_count | count |
# +---------------+--------------+-------+
# | The Cool Kids |      3       |   2   |
# | The Cool Kids |      4       |   4   |
# | The Cool Kids |      7       |   1   |
# | The Cool Kids |      8       |   1   |
# | The Cool Kids |      2       |   5   |
# | The Cool Kids |      1       |   26  |
# +---------------+--------------+-------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
b[b['artist']=='Kanye West']
# Out:
# Columns:
# 	artist	str
# 	listen_count	int
# 	count	int
#
# Rows: Unknown
#
# Data:
# +------------+--------------+-------+
# |   artist   | listen_count | count |
# +------------+--------------+-------+
# | Kanye West |      3       |  247  |
# | Kanye West |      12      |   14  |
# | Kanye West |      16      |   10  |
# | Kanye West |      41      |   1   |
# | Kanye West |      23      |   4   |
# | Kanye West |      4       |  154  |
# | Kanye West |      17      |   7   |
# | Kanye West |      33      |   1   |
# | Kanye West |      11      |   18  |
# | Kanye West |      18      |   3   |
# +------------+--------------+-------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
b[b['artist']=='William Tabbert']
# Out:
# Columns:
# 	artist	str
# 	listen_count	int
# 	count	int
#
# Rows: Unknown
#
# Data:
# +-----------------+--------------+-------+
# |      artist     | listen_count | count |
# +-----------------+--------------+-------+
# | William Tabbert |      3       |   1   |
# | William Tabbert |      1       |   11  |
# +-----------------+--------------+-------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %%
b[b['artist']=='Velvet Underground & Nico']
# Out:
# Columns:
# 	artist	str
# 	listen_count	int
# 	count	int
#
# Rows: Unknown
#
# Data:
# +---------------------------+--------------+-------+
# |           artist          | listen_count | count |
# +---------------------------+--------------+-------+
# | Velvet Underground & Nico |      4       |   2   |
# | Velvet Underground & Nico |      3       |   4   |
# | Velvet Underground & Nico |      1       |   42  |
# | Velvet Underground & Nico |      2       |   6   |
# | Velvet Underground & Nico |      6       |   1   |
# +---------------------------+--------------+-------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.
